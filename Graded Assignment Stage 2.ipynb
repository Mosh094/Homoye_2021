# %% [markdown]
# # Importing Relevant Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import  mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

# %%
df=pd.read_csv('energydata_complete.csv')
df
# Out:
#                    date  Appliances  lights         T1       RH_1         T2  \
# 0      11/01/2016 17:00          60      30  19.890000  47.596667  19.200000
# 1      11/01/2016 17:10          60      30  19.890000  46.693333  19.200000
# 2      11/01/2016 17:20          50      30  19.890000  46.300000  19.200000
# 3      11/01/2016 17:30          50      40  19.890000  46.066667  19.200000
# 4      11/01/2016 17:40          60      40  19.890000  46.333333  19.200000
# ...                 ...         ...     ...        ...        ...        ...
# 19730  27/05/2016 17:20         100       0  25.566667  46.560000  25.890000
# 19731  27/05/2016 17:30          90       0  25.500000  46.500000  25.754000
# 19732  27/05/2016 17:40         270      10  25.500000  46.596667  25.628571
# 19733  27/05/2016 17:50         420      10  25.500000  46.990000  25.414000
# 19734  27/05/2016 18:00         430      10  25.500000  46.600000  25.264286
#
#             RH_2         T3       RH_3         T4  ...         T9     RH_9  \
# 0      44.790000  19.790000  44.730000  19.000000  ...  17.033333  45.5300
# 1      44.722500  19.790000  44.790000  19.000000  ...  17.066667  45.5600
# 2      44.626667  19.790000  44.933333  18.926667  ...  17.000000  45.5000
# 3      44.590000  19.790000  45.000000  18.890000  ...  17.000000  45.4000
# 4      44.530000  19.790000  45.000000  18.890000  ...  17.000000  45.4000
# ...          ...        ...        ...        ...  ...        ...      ...
# 19730  42.025714  27.200000  41.163333  24.700000  ...  23.200000  46.7900
# 19731  42.080000  27.133333  41.223333  24.700000  ...  23.200000  46.7900
# 19732  42.768571  27.050000  41.690000  24.700000  ...  23.200000  46.7900
# 19733  43.036000  26.890000  41.290000  24.700000  ...  23.200000  46.8175
# 19734  42.971429  26.823333  41.156667  24.700000  ...  23.200000  46.8450
#
#        T_out  Press_mm_hg     RH_out  Windspeed  Visibility  Tdewpoint  \
# 0       6.60        733.5  92.000000   7.000000   63.000000        5.3
# 1       6.48        733.6  92.000000   6.666667   59.166667        5.2
# 2       6.37        733.7  92.000000   6.333333   55.333333        5.1
# 3       6.25        733.8  92.000000   6.000000   51.500000        5.0
# 4       6.13        733.9  92.000000   5.666667   47.666667        4.9
# ...      ...          ...        ...        ...         ...        ...
# 19730  22.70        755.2  55.666667   3.333333   23.666667       13.3
# 19731  22.60        755.2  56.000000   3.500000   24.500000       13.3
# 19732  22.50        755.2  56.333333   3.666667   25.333333       13.3
# 19733  22.30        755.2  56.666667   3.833333   26.166667       13.2
# 19734  22.20        755.2  57.000000   4.000000   27.000000       13.2
#
#              rv1        rv2
# 0      13.275433  13.275433
# 1      18.606195  18.606195
# 2      28.642668  28.642668
# 3      45.410390  45.410390
# 4      10.084097  10.084097
# ...          ...        ...
# 19730  43.096812  43.096812
# 19731  49.282940  49.282940
# 19732  29.199117  29.199117
# 19733   6.322784   6.322784
# 19734  34.118851  34.118851
#
# [19735 rows x 29 columns]

# %% [markdown]
# # Rename Columns

# %% [markdown]
# Get List of Columns

# %%
df.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %% [markdown]
# Assign New Titles to Columns

# %%
column_names = {'date':'date' , 'Appliances':'Appliances', 'lights':'lights', 'T1':'Temp_kitchen', 'RH_1':'Humd_kitchen', 
                'T2':'Temp_living_room', 'RH_2':'Humd_living_room', 'T3': 'Temp_laundry_room','RH_3': 'Humd_laundry_room',
                'T4': 'Temp_office_room', 'RH_4': 'Humd_ofice', 'T5': 'Temp_bathroom', 'RH_5':'Humd_bathroom', 
                'T6':'Temp_oute_building','RH_6':'Humd_out_building', 'T7': 'Temp_ironing_room', 'RH_7': 'Humd_ironing_room', 
                'T8': 'Temp_teen_room2','RH_8':'Humd_in_teen_room2', 'T9':'Temp_parents_room', 'RH_9': 'Humd_parents_room',
                'T_out':'Temp_out', 'Press_mm_hg': 'Press_mm_hg', 'RH_out': 'Humd_out', 'Windspeed':'Windspeed',
                'Visibility': 'Visibility', 'Tdewpoint':'Tdewpoint', 'rv1': 'Random_var1', 'rv2':'Random_var2'}

# %% [markdown]
# Merge New Columns with Dataset

# %%
df = df.rename(columns=column_names)
df
# Out:
#                    date  Appliances  lights  Temp_kitchen  Humd_kitchen  \
# 0      11/01/2016 17:00          60      30     19.890000     47.596667
# 1      11/01/2016 17:10          60      30     19.890000     46.693333
# 2      11/01/2016 17:20          50      30     19.890000     46.300000
# 3      11/01/2016 17:30          50      40     19.890000     46.066667
# 4      11/01/2016 17:40          60      40     19.890000     46.333333
# ...                 ...         ...     ...           ...           ...
# 19730  27/05/2016 17:20         100       0     25.566667     46.560000
# 19731  27/05/2016 17:30          90       0     25.500000     46.500000
# 19732  27/05/2016 17:40         270      10     25.500000     46.596667
# 19733  27/05/2016 17:50         420      10     25.500000     46.990000
# 19734  27/05/2016 18:00         430      10     25.500000     46.600000
#
#        Temp_living_room  Humd_living_room  Temp_laundry_room  \
# 0             19.200000         44.790000          19.790000
# 1             19.200000         44.722500          19.790000
# 2             19.200000         44.626667          19.790000
# 3             19.200000         44.590000          19.790000
# 4             19.200000         44.530000          19.790000
# ...                 ...               ...                ...
# 19730         25.890000         42.025714          27.200000
# 19731         25.754000         42.080000          27.133333
# 19732         25.628571         42.768571          27.050000
# 19733         25.414000         43.036000          26.890000
# 19734         25.264286         42.971429          26.823333
#
#        Humd_laundry_room  Temp_office_room  ...  Temp_parents_room  \
# 0              44.730000         19.000000  ...          17.033333
# 1              44.790000         19.000000  ...          17.066667
# 2              44.933333         18.926667  ...          17.000000
# 3              45.000000         18.890000  ...          17.000000
# 4              45.000000         18.890000  ...          17.000000
# ...                  ...               ...  ...                ...
# 19730          41.163333         24.700000  ...          23.200000
# 19731          41.223333         24.700000  ...          23.200000
# 19732          41.690000         24.700000  ...          23.200000
# 19733          41.290000         24.700000  ...          23.200000
# 19734          41.156667         24.700000  ...          23.200000
#
#        Humd_parents_room  Temp_out  Press_mm_hg   Humd_out  Windspeed  \
# 0                45.5300      6.60        733.5  92.000000   7.000000
# 1                45.5600      6.48        733.6  92.000000   6.666667
# 2                45.5000      6.37        733.7  92.000000   6.333333
# 3                45.4000      6.25        733.8  92.000000   6.000000
# 4                45.4000      6.13        733.9  92.000000   5.666667
# ...                  ...       ...          ...        ...        ...
# 19730            46.7900     22.70        755.2  55.666667   3.333333
# 19731            46.7900     22.60        755.2  56.000000   3.500000
# 19732            46.7900     22.50        755.2  56.333333   3.666667
# 19733            46.8175     22.30        755.2  56.666667   3.833333
# 19734            46.8450     22.20        755.2  57.000000   4.000000
#
#        Visibility  Tdewpoint  Random_var1  Random_var2
# 0       63.000000        5.3    13.275433    13.275433
# 1       59.166667        5.2    18.606195    18.606195
# 2       55.333333        5.1    28.642668    28.642668
# 3       51.500000        5.0    45.410390    45.410390
# 4       47.666667        4.9    10.084097    10.084097
# ...           ...        ...          ...          ...
# 19730   23.666667       13.3    43.096812    43.096812
# 19731   24.500000       13.3    49.282940    49.282940
# 19732   25.333333       13.3    29.199117    29.199117
# 19733   26.166667       13.2     6.322784     6.322784
# 19734   27.000000       13.2    34.118851    34.118851
#
# [19735 rows x 29 columns]

# %%
simple_linear_reg_df = df[['Temp_living_room', 'Temp_out']].sample(15, random_state=2)
simple_linear_reg_df
# Out:
#        Temp_living_room  Temp_out
# 1117          17.426667     -2.27
# 16275         22.760000     14.20
# 13272         21.230000     10.50
# 3160          21.100000      7.50
# 19210         21.856667     10.70
# 8260          17.356667      4.47
# 12299         19.000000      6.50
# 13505         22.700000     13.30
# 12913         19.593333      5.95
# 17788         21.890000      8.73
# 17894         21.500000      6.67
# 7665          19.142857      1.50
# 10165         18.000000      0.85
# 18809         22.400000     14.30
# 8737          17.066667      1.57

# %%
sns.regplot(x='Temp_living_room', y= 'Temp_out', data=simple_linear_reg_df)
# Out:
# <AxesSubplot:xlabel='Temp_living_room', ylabel='Temp_out'>

# %% [markdown]
# # Normalising the Dataset To A Common Scale Using The Min Max Scaler

# %% [markdown]
# Drop Date and Light(not influenced by other temp and press) which seems irrelevant

# %%
df = df.drop(columns=['date','lights'])
df
# Out:
#        Appliances  Temp_kitchen  Humd_kitchen  Temp_living_room  \
# 0              60     19.890000     47.596667         19.200000
# 1              60     19.890000     46.693333         19.200000
# 2              50     19.890000     46.300000         19.200000
# 3              50     19.890000     46.066667         19.200000
# 4              60     19.890000     46.333333         19.200000
# ...           ...           ...           ...               ...
# 19730         100     25.566667     46.560000         25.890000
# 19731          90     25.500000     46.500000         25.754000
# 19732         270     25.500000     46.596667         25.628571
# 19733         420     25.500000     46.990000         25.414000
# 19734         430     25.500000     46.600000         25.264286
#
#        Humd_living_room  Temp_laundry_room  Humd_laundry_room  \
# 0             44.790000          19.790000          44.730000
# 1             44.722500          19.790000          44.790000
# 2             44.626667          19.790000          44.933333
# 3             44.590000          19.790000          45.000000
# 4             44.530000          19.790000          45.000000
# ...                 ...                ...                ...
# 19730         42.025714          27.200000          41.163333
# 19731         42.080000          27.133333          41.223333
# 19732         42.768571          27.050000          41.690000
# 19733         43.036000          26.890000          41.290000
# 19734         42.971429          26.823333          41.156667
#
#        Temp_office_room  Humd_ofice  Temp_bathroom  ...  Temp_parents_room  \
# 0             19.000000   45.566667      17.166667  ...          17.033333
# 1             19.000000   45.992500      17.166667  ...          17.066667
# 2             18.926667   45.890000      17.166667  ...          17.000000
# 3             18.890000   45.723333      17.166667  ...          17.000000
# 4             18.890000   45.530000      17.200000  ...          17.000000
# ...                 ...         ...            ...  ...                ...
# 19730         24.700000   45.590000      23.200000  ...          23.200000
# 19731         24.700000   45.590000      23.230000  ...          23.200000
# 19732         24.700000   45.730000      23.230000  ...          23.200000
# 19733         24.700000   45.790000      23.200000  ...          23.200000
# 19734         24.700000   45.963333      23.200000  ...          23.200000
#
#        Humd_parents_room  Temp_out  Press_mm_hg   Humd_out  Windspeed  \
# 0                45.5300      6.60        733.5  92.000000   7.000000
# 1                45.5600      6.48        733.6  92.000000   6.666667
# 2                45.5000      6.37        733.7  92.000000   6.333333
# 3                45.4000      6.25        733.8  92.000000   6.000000
# 4                45.4000      6.13        733.9  92.000000   5.666667
# ...                  ...       ...          ...        ...        ...
# 19730            46.7900     22.70        755.2  55.666667   3.333333
# 19731            46.7900     22.60        755.2  56.000000   3.500000
# 19732            46.7900     22.50        755.2  56.333333   3.666667
# 19733            46.8175     22.30        755.2  56.666667   3.833333
# 19734            46.8450     22.20        755.2  57.000000   4.000000
#
#        Visibility  Tdewpoint  Random_var1  Random_var2
# 0       63.000000        5.3    13.275433    13.275433
# 1       59.166667        5.2    18.606195    18.606195
# 2       55.333333        5.1    28.642668    28.642668
# 3       51.500000        5.0    45.410390    45.410390
# 4       47.666667        4.9    10.084097    10.084097
# ...           ...        ...          ...          ...
# 19730   23.666667       13.3    43.096812    43.096812
# 19731   24.500000       13.3    49.282940    49.282940
# 19732   25.333333       13.3    29.199117    29.199117
# 19733   26.166667       13.2     6.322784     6.322784
# 19734   27.000000       13.2    34.118851    34.118851
#
# [19735 rows x 27 columns]

# %%
scaler = MinMaxScaler()
normalised_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
features_df = normalised_df.drop(columns=['Appliances'])
energy_target = normalised_df['Appliances']

# %% [markdown]
# # Split Dataset Into The Training And Testing dataset.

# %%
x_train, x_test, y_train, y_test = train_test_split(features_df, energy_target, test_size=0.3, random_state=42)

# %% [markdown]
# # Perform Linear Model

# %% [markdown]
# Declare Model Type

# %%
linear_model = LinearRegression()

# %% [markdown]
# Fit the model to the training dataset

# %%
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Obtain predictions

# %%
predicted_values = linear_model.predict(x_test)

# %% [markdown]
# # Measuring Performance

# %% [markdown]
# Mean_absolute_error

# %%
mae = mean_absolute_error(y_test, predicted_values)
round(mae, 3)
# Out:
# 0.05

# %% [markdown]
# R-Squared

# %%
r2_score = r2_score(y_test, predicted_values)
round(r2_score, 3)
# Out:
# 0.149

# %% [markdown]
# Residual Sum of Square

# %%
rss = np.sum(np.square(y_test - predicted_values))
round(rss, 3)
# Out:
# 45.348

# %% [markdown]
# Root Mean Squared Error

# %%
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
round(rmse, 3)
# Out:
# 0.088

# %% [markdown]
# # Penalisation Methods

# %% [markdown]
# Ridge Regression

# %%
ridge_reg = Ridge(alpha=0.5)
ridge_reg.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.5)

# %% [markdown]
# Feature Selection and Lasso Regression - Least Absolute Shrinkage and Selection Operator

# %%
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.001)

# %% [markdown]
# Comparing the effects of regularisation

# %%
def get_weights_df(model, feat, col_name):
  #this function returns the weight of every feature
  weights = pd.Series(model.coef_, feat.columns).sort_values()
  weights_df = pd.DataFrame(weights).reset_index()
  weights_df.columns = ['Features', col_name]
  weights_df[col_name].round(3)
  return weights_df

linear_model_weights = get_weights_df(linear_model, x_train, 'Linear_Model_Weight')
ridge_weights_df = get_weights_df(ridge_reg, x_train, 'Ridge_Weight')
lasso_weights_df = get_weights_df(lasso_reg, x_train, 'Lasso_weight')

final_weights = pd.merge(linear_model_weights, ridge_weights_df, on='Features')
final_weights = pd.merge(final_weights, lasso_weights_df, on='Features')
final_weights
# Out:
#               Features  Linear_Model_Weight  Ridge_Weight  Lasso_weight
# 0     Humd_living_room            -0.456662     -0.401113     -0.000000
# 1             Temp_out            -0.321969     -0.250943      0.000000
# 2     Temp_living_room            -0.236198     -0.193899      0.000000
# 3    Temp_parents_room            -0.189977     -0.188615     -0.000000
# 4   Humd_in_teen_room2            -0.157585     -0.156584     -0.000110
# 5             Humd_out            -0.077748     -0.050642     -0.049557
# 6    Humd_ironing_room            -0.044620     -0.046297     -0.000000
# 7    Humd_parents_room            -0.039808     -0.041707     -0.000000
# 8        Temp_bathroom            -0.015645     -0.020714     -0.000000
# 9         Temp_kitchen            -0.003242     -0.021515      0.000000
# 10         Random_var1             0.000765      0.000740     -0.000000
# 11         Random_var2             0.000765      0.000740     -0.000000
# 12         Press_mm_hg             0.006832      0.006511     -0.000000
# 13   Temp_ironing_room             0.010350      0.010048     -0.000000
# 14          Visibility             0.012306      0.012032      0.000000
# 15       Humd_bathroom             0.016009      0.016177      0.000000
# 16          Humd_ofice             0.026370      0.024155      0.000000
# 17    Temp_office_room             0.028957      0.026986     -0.000000
# 18           Windspeed             0.029178      0.030457      0.002912
# 19   Humd_out_building             0.038023      0.035006     -0.000000
# 20   Humd_laundry_room             0.096095      0.095012      0.000000
# 21     Temp_teen_room2             0.101995      0.100753      0.000000
# 22           Tdewpoint             0.117862      0.076804      0.000000
# 23  Temp_oute_building             0.236441      0.213350      0.000000
# 24   Temp_laundry_room             0.290587      0.287377      0.000000
# 25        Humd_kitchen             0.553516      0.511910      0.017880
